# %%
# %pip install openai

# %%
from openai import OpenAI

# %%
import os

from dotenv import load_dotenv
load_dotenv()

openai_api_key = os.getenv("OPENAI_API_KEY")

openai_client = OpenAI(api_key = openai_api_key)
print("OpenAI client successfully configured.")

print(openai_api_key[:5])
# Out:
# OpenAI client successfully configured.
# sk-pr

# %%
system_prompt = {
                    "role": "system",
                    "content": f"""
                    You are a helpfull E-Commerce assistant helping customers with their general questions regarding policies and procedures when buying in our store.
                    Our store sells e-books and courses for IT professionals.
                    """,
                }

# %%
def simple_chatbot(messages, openai_client, model="gpt-4o"):
    response = openai_client.chat.completions.create(
        model=model,
        messages=messages,
        max_tokens=250,
    )
    return response.choices[0].message.content

# %%
query = "What is your return policy?"

user_query = {"role":"user", "content":query}
messages = [system_prompt, user_query]
response = simple_chatbot(messages, openai_client)
print(f"Bot: {response}")
# Out:
# Bot: Our store specializes in digital products such as e-books and courses for IT professionals. Due to the nature of digital goods, we typically do not offer returns or refunds after a purchase is completed. However, we are committed to customer satisfaction and understand that there may be exceptional circumstances.
#
# If you encounter any issues with your purchase, such as technical difficulties accessing the content or receiving the incorrect product, please reach out to our customer service team. We will do our best to assist you and resolve any problems. In some cases, we may offer a refund or exchange on a case-by-case basis, at our discretion.
#
# Please make sure to review product descriptions and specifications carefully before purchasing to ensure that the product meets your expectations and needs.
